# %%
import sys
sys.path.append('..')

from sklearn import datasets
from sklearn.model_selection import train_test_split
from models.LogisticRegression import LogisticRegression

SEED= 42

bc = datasets.load_breast_cancer()
X, y = bc.data, bc.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = SEED)

lg = LogisticRegression(lr=0.01)
lg.fit(X_train, y_train)

predictions = lg.predict(X_test)

acc = lg.accuracy_score(y_test, predictions)

print(acc)
# Out:
# 0.9473684210526315
# /Users/m1/Desktop/ml-from-scratch/tests/../models/LogisticRegression.py:17: RuntimeWarning: overflow encountered in exp
#   h = 1 / (1 + np.exp(-y_pred))
# /Users/m1/Desktop/ml-from-scratch/tests/../models/LogisticRegression.py:25: RuntimeWarning: overflow encountered in exp
#   prob = 1 / (1 + np.exp(-y_pred))
